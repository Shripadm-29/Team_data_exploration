# %%
print("Hello")
# Out:
# Hello

# %%
import pandas
#import seaborn
#import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

chipotle_data = pandas.read_csv(url, sep = '\t')

chipotle_data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipotle_data.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %% [markdown]
# There a total of 4622 orders
# The mean is about 927
# The standard deviation lies around 529
# Minimum: 1
# 1st quartile: 477
# 2nd quartile: 926
# third quartile: 1393
# Maximum: 1834

# %%
chipotle_data.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Mangavalli\Documents\GitHub\Team_data_exploration\Untitled-1.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mangavalli/Documents/GitHub/Team_data_exploration/Untitled-1.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> chipotle_data.columns()
#
# TypeError: 'Index' object is not callable

# %%
chipotle_data.sort_values(by='quantity')
# Out:
#       order_id  quantity                     item_name  \
# 0            1         1  Chips and Fresh Tomato Salsa
# 3020      1201         1                   Canned Soda
# 3021      1201         1                 Bottled Water
# 3022      1201         1                 Side of Chips
# 3023      1202         1                  Chicken Bowl
# ...        ...       ...                           ...
# 2441       970         5                 Bottled Water
# 3599      1443         7                 Bottled Water
# 3887      1559         8                 Side of Chips
# 4152      1660        10                 Bottled Water
# 3598      1443        15  Chips and Fresh Tomato Salsa
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 3020                                  [Diet Dr. Pepper]     $1.09
# 3021                                                NaN     $1.09
# 3022                                                NaN     $1.69
# 3023  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...     $8.49
# ...                                                 ...        ...
# 2441                                                NaN     $7.50
# 3599                                                NaN    $10.50
# 3887                                                NaN    $13.52
# 4152                                                NaN    $15.00
# 3598                                                NaN    $44.25
#
# [4622 rows x 5 columns]

# %% [markdown]
# The most ordered item would be Chips and Fresh Tomato Salsa
